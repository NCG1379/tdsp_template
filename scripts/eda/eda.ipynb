# %%
import pandas as pd
import time
import sys
import gc
import os

from dotenv import load_dotenv

# %% [markdown]
# ### Generación de datos:

# %% [markdown]
# #### Definición:
#
# Este proyecto está dirigido a la creación de agentes útiles en el área de investigación de IOCs en ciberseguridad.
#
# Un agente se entiende en este sentido, como la combinación de un LLM, un prompt y piezas de código que puede ejecutar según el caso lo requiera, conocidas como herramientas. Actualmente se han definido diferentes arquitecturas, diseñadas para permitir la interacción entre agentes para cumplir una tarea bien definida, así como otras más simples que buscan aumentar las capacidades del LLM para obtener la información que le permita llevar a cabo el requerimiento del prompt inicial.

# %%
class DataGeneration(dtaq.IOCValidatedModel):

    def generation_API_call(self):
        """Function to evaluate the data of APIs using a document to extract information to analyze the
        behaviour of information that is brought by each CTI web tool"""

        ioc_value, ioc_type = self.ioc
        if ioc_type == "ip":
            ## Virus Total:
            virustotal = dtaq.VirusTotal(ioc=ioc_value).display_ip_info()

            ## AbuseIPDB
            abuseipdb = dtaq.AbuseIPDB(ioc=ioc_value).check_ip()
            
            ## Whois
            whois_adap = dtaq.WHOIS_RDAP(ioc=ioc_value).get_whois_data()

            ## Shodan IP
            shodan = dtaq.ShodanIO(ioc=ioc_value).search_data_in_shodan()

            return self.dataframe_report(ioc_value, virustotal, abuseipdb, whois_adap, shodan)


        elif ioc_type == "domain":

            ## Virus Total:
            virustotal = dtaq.VirusTotal(ioc=ioc_value).display_domain_info()
            ## AbuseIPDB
            abuseipdb = "No aplica"
            ## Whois
            whois_adap = "No aplica"
            ## Shodan Domain
            shodan = dtaq.ShodanIO(ioc=ioc_value).search_data_in_shodan()

            return self.dataframe_report(ioc_value, virustotal, abuseipdb, whois_adap, shodan)
        
        else:
            ## Virus Total:
            virustotal = dtaq.VirusTotal(ioc=ioc_value)

            ## AbuseIPDB
            abuseipdb = dtaq.AbuseIPDB(ioc=ioc_value).check_ip()
            
            ## Whois
            whois_adap = dtaq.WHOIS_RDAP(ioc=ioc_value).get_whois_data()

            ## Shodan IP
            shodan = dtaq.ShodanIO(ioc=ioc_value).search_data_in_shodan()
            ## Shodan Domain
            if shodan == {}:
                shodan = dtaq.ShodanIO(ioc=ioc_value).search_data_in_shodan()

            return self.dataframe_report(ioc_value, virustotal, abuseipdb, whois_adap, shodan)

            

    def dataframe_report(self, ioc_value, virustotal, abuseipdb, whois_adap, shodan):
        """Function to complete the pandas data frame of responses base on iocs present in a document"""
        
        report = pd.DataFrame([{"IoC": str(ioc_value), "VirusTotal": str(virustotal), "AbuseIPDB": str(abuseipdb), "Whois_rdap": str(whois_adap), "Shodan.io": str(shodan), "Data_Time": str(self.time_report_generation())}], index=[0])

        # print(type(virustotal))
        """
        report["IoC"]   =  str(ioc_value)
        report["VirusTotal"]  = str(virustotal)
        report["AbuseIPDB"]   = str(abuseipdb)
        report["Whois_rdap"]  = str(whois_adap)
        report["Shodan.io"]   = str(shodan)
        report["Data_Time"]   = str(self.time_report_generation())
        """
        # print(report)

        return report
    
    def time_report_generation(self):
        
        s = strftime("%a_%d_%b_%Y %H-%M", localtime(time.time()))

        return s
    
    
    def createreport_toexcel(self, data):

        if not os.path.exists("scripts\\eda\\data"):
            os.makedirs("scripts\\eda\\data")

        return data.to_excel("scripts\\eda\\data\\Reporte_APIs_validation_" + str(self.time_report_generation()) + ".xlsx", sheet_name="Reporte_APIs")

# %% [markdown]
# ### Almacenamiento de datos:

# %%
from pymongo import MongoClient
import pandas as pd

client = MongoClient('mongodb://localhost:27017')
db = 'langchainAgent'

def query_db(collection: str, query: dict):
    collection = client.get_database(db).get_collection(collection)
    return pd.DataFrame(list(collection.find(query)))

def insert_docs_to_db(docs: dict, collection: str):
    collection = client.get_database(db).get_collection(collection)
    collection.insert_many(docs)

# %% [markdown]
# ### Visualización de los Datos

# %%
df_vt = query_db("VirusTotal", {})
pd.json_normalize(df_vt.data).T.head(60)
# Out:
#                                                                                                     0  \
# id                                                                                     ambakgroup.com
# type                                                                                           domain
# links.self                                          https://www.virustotal.com/api/v3/domains/amba...
# attributes.last_https_certificate_date                                                     1729970117
# attributes.whois_date                                                                      1761264000
# attributes.tags                                                                                    []
# attributes.last_update_date                                                              1729728000.0
# attributes.jarm                                     05d10d20d21d20d05c05d10d05d20d74fcf6501ae7a923...
# attributes.last_analysis_date                                                              1752037321
# attributes.last_modification_date                                                          1752037329
# attributes.total_votes.harmless                                                                     0
# attributes.total_votes.malicious                                                                    3
# attributes.last_dns_records                         [{'type': 'MX', 'ttl': 1800, 'priority': 10, '...
# attributes.last_https_certificate.cert_signatur...                                          sha256RSA
# attributes.last_https_certificate.cert_signatur...  9b04a379db762874ddfe2afcbe1999ea630aafce5247fb...
# attributes.last_https_certificate.extensions.CA                                                 False
# attributes.last_https_certificate.extensions.ke...  [digitalSignature, keyEncipherment, nonRepudia...
# attributes.last_https_certificate.validity.not_...                                2025-10-24 05:38:38
# attributes.last_https_certificate.validity.not_...                                2024-10-24 05:38:38
# attributes.last_https_certificate.size                                                           1014
# attributes.last_https_certificate.version                                                          V3
# attributes.last_https_certificate.public_key.al...                                                RSA
# attributes.last_https_certificate.public_key.rs...  a8f22f54a7488ed1433b1155a43ec674806a1f9bd4d0f8...
# attributes.last_https_certificate.public_key.rs...                                              10001
# attributes.last_https_certificate.public_key.rs...                                               2048
# attributes.last_https_certificate.thumbprint_sh...  298b1835fc593337c257dfed2a70495c47f0dfa5642cb7...
# attributes.last_https_certificate.thumbprint                 bc1739419292857862900ff4f037df0d9cbf417d
# attributes.last_https_certificate.serial_number                                                  15d2
# attributes.last_https_certificate.issuer.C                                                         --
# attributes.last_https_certificate.issuer.ST                                                 SomeState
# attributes.last_https_certificate.issuer.L                                                   SomeCity
# attributes.last_https_certificate.issuer.O                                           SomeOrganization
# attributes.last_https_certificate.issuer.OU                                    SomeOrganizationalUnit
# attributes.last_https_certificate.issuer.CN                                            ambakgroup.com
# attributes.last_https_certificate.issuer.1.2.84...                                root@ambakgroup.com
# attributes.last_https_certificate.subject.C                                                        --
# attributes.last_https_certificate.subject.ST                                                SomeState
# attributes.last_https_certificate.subject.L                                                  SomeCity
# attributes.last_https_certificate.subject.O                                          SomeOrganization
# attributes.last_https_certificate.subject.OU                                   SomeOrganizationalUnit
# attributes.last_https_certificate.subject.CN                                           ambakgroup.com
# attributes.last_https_certificate.subject.1.2.8...                                root@ambakgroup.com
# attributes.reputation                                                                             -13
# attributes.last_analysis_results.Acronis.method                                             blacklist
# attributes.last_analysis_results.Acronis.engine...                                            Acronis
# attributes.last_analysis_results.Acronis.category                                            harmless
# attributes.last_analysis_results.Acronis.result                                                 clean
# attributes.last_analysis_results.0xSI_f33d.method                                           blacklist
# attributes.last_analysis_results.0xSI_f33d.engi...                                          0xSI_f33d
# attributes.last_analysis_results.0xSI_f33d.cate...                                         undetected
# attributes.last_analysis_results.0xSI_f33d.result                                             unrated
# attributes.last_analysis_results.Abusix.method                                              blacklist
# attributes.last_analysis_results.Abusix.engine_...                                             Abusix
# attributes.last_analysis_results.Abusix.category                                             harmless
# attributes.last_analysis_results.Abusix.result                                                  clean
# attributes.last_analysis_results.ADMINUSLabs.me...                                          blacklist
# attributes.last_analysis_results.ADMINUSLabs.en...                                        ADMINUSLabs
# attributes.last_analysis_results.ADMINUSLabs.ca...                                           harmless
# attributes.last_analysis_results.ADMINUSLabs.re...                                              clean
# attributes.last_analysis_results.Axur.method                                                blacklist
#
#                                                                                                     1
# id                                                                                       64.137.9.118
# type                                                                                       ip_address
# links.self                                          https://www.virustotal.com/api/v3/ip_addresses...
# attributes.last_https_certificate_date                                                     1744386520
# attributes.whois_date                                                                      1750870838
# attributes.tags                                                                                    []
# attributes.last_update_date                                                                       NaN
# attributes.jarm                                     21d19d00021d21d00042d43d0000005ad20eceaf7f71ae...
# attributes.last_analysis_date                                                              1752035674
# attributes.last_modification_date                                                          1752036333
# attributes.total_votes.harmless                                                                     0
# attributes.total_votes.malicious                                                                    1
# attributes.last_dns_records                                                                       NaN
# attributes.last_https_certificate.cert_signatur...                                          sha256RSA
# attributes.last_https_certificate.cert_signatur...  8a322b1d55d71e361a452f2d383a102128458257fe35c0...
# attributes.last_https_certificate.extensions.CA                                                 False
# attributes.last_https_certificate.extensions.ke...                [digitalSignature, keyEncipherment]
# attributes.last_https_certificate.validity.not_...                                2025-10-09 19:53:00
# attributes.last_https_certificate.validity.not_...                                2025-03-09 19:53:00
# attributes.last_https_certificate.size                                                           1932
# attributes.last_https_certificate.version                                                          V3
# attributes.last_https_certificate.public_key.al...                                                RSA
# attributes.last_https_certificate.public_key.rs...  c4ee77d25809e121ccb93d3070b9cb6b1134609274a71b...
# attributes.last_https_certificate.public_key.rs...                                              10001
# attributes.last_https_certificate.public_key.rs...                                               4096
# attributes.last_https_certificate.thumbprint_sh...  3aaeef3928df3f7a596c52bf3afd46d96f3f1f7380f7eb...
# attributes.last_https_certificate.thumbprint                 16f938f235608f9d4d2c573b8a72e46f1e9a9fec
# attributes.last_https_certificate.serial_number                              13c5608fe7047bfa0d0d0197
# attributes.last_https_certificate.issuer.C                                                         BE
# attributes.last_https_certificate.issuer.ST                                                       NaN
# attributes.last_https_certificate.issuer.L                                                        NaN
# attributes.last_https_certificate.issuer.O                                           GlobalSign nv-sa
# attributes.last_https_certificate.issuer.OU                                                       NaN
# attributes.last_https_certificate.issuer.CN                          GlobalSign GCC R3 DV TLS CA 2020
# attributes.last_https_certificate.issuer.1.2.84...                                                NaN
# attributes.last_https_certificate.subject.C                                                       NaN
# attributes.last_https_certificate.subject.ST                                                      NaN
# attributes.last_https_certificate.subject.L                                                       NaN
# attributes.last_https_certificate.subject.O                                                       NaN
# attributes.last_https_certificate.subject.OU                                                      NaN
# attributes.last_https_certificate.subject.CN                                           www.qu-tech.ru
# attributes.last_https_certificate.subject.1.2.8...                                                NaN
# attributes.reputation                                                                             -11
# attributes.last_analysis_results.Acronis.method                                             blacklist
# attributes.last_analysis_results.Acronis.engine...                                            Acronis
# attributes.last_analysis_results.Acronis.category                                            harmless
# attributes.last_analysis_results.Acronis.result                                                 clean
# attributes.last_analysis_results.0xSI_f33d.method                                           blacklist
# attributes.last_analysis_results.0xSI_f33d.engi...                                          0xSI_f33d
# attributes.last_analysis_results.0xSI_f33d.cate...                                         undetected
# attributes.last_analysis_results.0xSI_f33d.result                                             unrated
# attributes.last_analysis_results.Abusix.method                                              blacklist
# attributes.last_analysis_results.Abusix.engine_...                                             Abusix
# attributes.last_analysis_results.Abusix.category                                             harmless
# attributes.last_analysis_results.Abusix.result                                                  clean
# attributes.last_analysis_results.ADMINUSLabs.me...                                          blacklist
# attributes.last_analysis_results.ADMINUSLabs.en...                                        ADMINUSLabs
# attributes.last_analysis_results.ADMINUSLabs.ca...                                           harmless
# attributes.last_analysis_results.ADMINUSLabs.re...                                              clean
# attributes.last_analysis_results.Axur.method                                                blacklist

# %%
df_abuse = query_db("AbuseIPDB", {})
df_abuse.T
# Out:
#                                                         0
# _id                              686e02eebd9e2a015a58c5f9
# ipAddress                                    64.137.9.118
# isPublic                                             True
# ipVersion                                               4
# isWhitelisted                                       False
# abuseConfidenceScore                                    0
# countryCode                                            US
# usageType                 Data Center/Web Hosting/Transit
# isp                   Individual Entrepreneur Anton Levin
# domain                                       vdska.online
# hostnames                                              []
# isTor                                               False
# totalReports                                            0
# numDistinctUsers                                        0
# lastReportedAt                  2025-04-09T16:54:32+00:00

# %%
df_whois = query_db("whois", {})
df_whois.T
# Out:
#                                                                  0
# _id                                       686e02febd9e2a015a58c5fa
# handle                                   64.137.9.0 - 64.137.9.255
# startAddress                                            64.137.9.0
# endAddress                                            64.137.9.255
# ipVersion                                                       v4
# name                                                       Voldeta
# type                                                   ASSIGNED PA
# country                                                         US
# parentHandle                           64.137.0.0 - 64.137.127.255
# cidr0_cidrs             [{'v4prefix': '64.137.9.0', 'length': 24}]
# status                                                    [active]
# entities         [{'handle': 'AL19394-RIPE', 'vcardArray': ['vc...
# links            [{'value': 'https://rdap.db.ripe.net/ip/64.137...
# events           [{'eventAction': 'registration', 'eventDate': ...
# rdapConformance  [geofeed1, rirSearch1, ips, cidr0, rdap_level_...
# notices          [{'title': 'Filtered', 'description': ['This o...
# port43                                              whois.ripe.net
# objectClassName                                         ip network
# redacted         [{'name': {'description': 'Personal e-mail inf...

# %%
df_shodan = query_db("Shodan", {})
df_shodan.T
# Out:
#                                 0
# _id      686e0339bd9e2a015a58c5fc
# matches                        []
# total                           0

# %% [markdown]
# ### Exploración:

# %% [markdown]
# #### Propósito:
#
# Se busca entonces, definir herramientas que pueda utilizar un LLM de forma "autónoma", para obtener más información sobre dominios o ips, asociados a indicadores de compromiso. Esto es debido a que, deendiendo de la naturaleza del IOC, la información disponible puede venir de diferentes endpoints, por ejemplo, herramientas como virustotal exponen rutas o urls diferentes para entregar información de cada tipo de indicador.
#
# Adicionalmente, en ciberseguridad, es común encontrar detecciones tardías, o que algunos proveedores tengan una latencia de horas, días o o incluso meses en lograr agregar contexto a los IOCs (información que sirve para entender el tipo de amenaza). Por lo que adicionalmente, se planea contar con un versionamiento de los datos, que puede habilitar otro tipo de información o comprensión de los atacantes, ya que puede servir de base para llevar a cabo investigaciones respecto al seguimiento de actores maliciosos.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
df_vt = pd.json_normalize(df_vt['data'])
df_vt
# Out:
#                id        type  \
# 0  ambakgroup.com      domain
# 1    64.137.9.118  ip_address
#
#                                           links.self  \
# 0  https://www.virustotal.com/api/v3/domains/amba...
# 1  https://www.virustotal.com/api/v3/ip_addresses...
#
#    attributes.last_https_certificate_date  attributes.whois_date  \
# 0                              1729970117             1761264000
# 1                              1744386520             1750870838
#
#   attributes.tags  attributes.last_update_date  \
# 0              []                 1.729728e+09
# 1              []                          NaN
#
#                                      attributes.jarm  \
# 0  05d10d20d21d20d05c05d10d05d20d74fcf6501ae7a923...
# 1  21d19d00021d21d00042d43d0000005ad20eceaf7f71ae...
#
#    attributes.last_analysis_date  attributes.last_modification_date  ...  \
# 0                     1752037321                         1752037329  ...
# 1                     1752035674                         1752036333  ...
#
#    attributes.rdap.country  attributes.rdap.parent_handle  \
# 0                      NaN                            NaN
# 1                       US    64.137.0.0 - 64.137.127.255
#
#                          attributes.rdap.cidr0_cidrs  \
# 0                                                NaN
# 1  [{'v4prefix': '64.137.9.0', 'length': 24, 'v6p...
#
#   attributes.rdap.arin_originas0_originautnums attributes.continent  \
# 0                                          NaN                  NaN
# 1                                           []                   NA
#
#    attributes.regional_internet_registry attributes.network attributes.asn  \
# 0                                    NaN                NaN            NaN
# 1                                   ARIN      64.137.9.0/24        49791.0
#
#   attributes.country  attributes.as_owner
# 0                NaN                  NaN
# 1                 US    Newserverlife LLC
#
# [2 rows x 478 columns]

# %%
df_vt.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2 entries, 0 to 1
# Data columns (total 478 columns):
#  #    Column                                                                         Dtype
# ---   ------                                                                         -----
#  0    id                                                                             object
#  1    type                                                                           object
#  2    links.self                                                                     object
#  3    attributes.last_https_certificate_date                                         int64
#  4    attributes.whois_date                                                          int64
#  5    attributes.tags                                                                object
#  6    attributes.last_update_date                                                    float64
#  7    attributes.jarm                                                                object
#  8    attributes.last_analysis_date                                                  int64
#  9    attributes.last_modification_date                                              int64
#  10   attributes.total_votes.harmless                                                int64
#  11   attributes.total_votes.malicious                                               int64
#  12   attributes.last_dns_records                                                    object
#  13   attributes.last_https_certificate.cert_signature.signature_algorithm           object
#  14   attributes.last_https_certificate.cert_signature.signature                     object
#  15   attributes.last_https_certificate.extensions.CA                                bool
#  16   attributes.last_https_certificate.extensions.key_usage                         object
#  17   attributes.last_https_certificate.validity.not_after                           object
#  18   attributes.last_https_certificate.validity.not_before                          object
#  19   attributes.last_https_certificate.size                                         int64
#  20   attributes.last_https_certificate.version                                      object
#  21   attributes.last_https_certificate.public_key.algorithm                         object
#  22   attributes.last_https_certificate.public_key.rsa.modulus                       object
#  23   attributes.last_https_certificate.public_key.rsa.exponent                      object
#  24   attributes.last_https_certificate.public_key.rsa.key_size                      int64
#  25   attributes.last_https_certificate.thumbprint_sha256                            object
#  26   attributes.last_https_certificate.thumbprint                                   object
#  27   attributes.last_https_certificate.serial_number                                object
#  28   attributes.last_https_certificate.issuer.C                                     object
#  29   attributes.last_https_certificate.issuer.ST                                    object
#  30   attributes.last_https_certificate.issuer.L                                     object
#  31   attributes.last_https_certificate.issuer.O                                     object
#  32   attributes.last_https_certificate.issuer.OU                                    object
#  33   attributes.last_https_certificate.issuer.CN                                    object
#  34   attributes.last_https_certificate.issuer.1.2.840.113549.1.9.1                  object
#  35   attributes.last_https_certificate.subject.C                                    object
#  36   attributes.last_https_certificate.subject.ST                                   object
#  37   attributes.last_https_certificate.subject.L                                    object
#  38   attributes.last_https_certificate.subject.O                                    object
#  39   attributes.last_https_certificate.subject.OU                                   object
#  40   attributes.last_https_certificate.subject.CN                                   object
#  41   attributes.last_https_certificate.subject.1.2.840.113549.1.9.1                 object
#  42   attributes.reputation                                                          int64
#  43   attributes.last_analysis_results.Acronis.method                                object
#  44   attributes.last_analysis_results.Acronis.engine_name                           object
#  45   attributes.last_analysis_results.Acronis.category                              object
#  46   attributes.last_analysis_results.Acronis.result                                object
#  47   attributes.last_analysis_results.0xSI_f33d.method                              object
#  48   attributes.last_analysis_results.0xSI_f33d.engine_name                         object
#  49   attributes.last_analysis_results.0xSI_f33d.category                            object
#  50   attributes.last_analysis_results.0xSI_f33d.result                              object
#  51   attributes.last_analysis_results.Abusix.method                                 object
#  52   attributes.last_analysis_results.Abusix.engine_name                            object
#  53   attributes.last_analysis_results.Abusix.category                               object
#  54   attributes.last_analysis_results.Abusix.result                                 object
#  55   attributes.last_analysis_results.ADMINUSLabs.method                            object
#  56   attributes.last_analysis_results.ADMINUSLabs.engine_name                       object
#  57   attributes.last_analysis_results.ADMINUSLabs.category                          object
#  58   attributes.last_analysis_results.ADMINUSLabs.result                            object
#  59   attributes.last_analysis_results.Axur.method                                   object
#  60   attributes.last_analysis_results.Axur.engine_name                              object
#  61   attributes.last_analysis_results.Axur.category                                 object
#  62   attributes.last_analysis_results.Axur.result                                   object
#  63   attributes.last_analysis_results.Criminal IP.method                            object
#  64   attributes.last_analysis_results.Criminal IP.engine_name                       object
#  65   attributes.last_analysis_results.Criminal IP.category                          object
#  66   attributes.last_analysis_results.Criminal IP.result                            object
#  67   attributes.last_analysis_results.AILabs (MONITORAPP).method                    object
#  68   attributes.last_analysis_results.AILabs (MONITORAPP).engine_name               object
#  69   attributes.last_analysis_results.AILabs (MONITORAPP).category                  object
#  70   attributes.last_analysis_results.AILabs (MONITORAPP).result                    object
#  71   attributes.last_analysis_results.AlienVault.method                             object
#  72   attributes.last_analysis_results.AlienVault.engine_name                        object
#  73   attributes.last_analysis_results.AlienVault.category                           object
#  74   attributes.last_analysis_results.AlienVault.result                             object
#  75   attributes.last_analysis_results.alphaMountain.ai.method                       object
#  76   attributes.last_analysis_results.alphaMountain.ai.engine_name                  object
#  77   attributes.last_analysis_results.alphaMountain.ai.category                     object
#  78   attributes.last_analysis_results.alphaMountain.ai.result                       object
#  79   attributes.last_analysis_results.AlphaSOC.method                               object
#  80   attributes.last_analysis_results.AlphaSOC.engine_name                          object
#  81   attributes.last_analysis_results.AlphaSOC.category                             object
#  82   attributes.last_analysis_results.AlphaSOC.result                               object
#  83   attributes.last_analysis_results.Antiy-AVL.method                              object
#  84   attributes.last_analysis_results.Antiy-AVL.engine_name                         object
#  85   attributes.last_analysis_results.Antiy-AVL.category                            object
#  86   attributes.last_analysis_results.Antiy-AVL.result                              object
#  87   attributes.last_analysis_results.ArcSight Threat Intelligence.method           object
#  88   attributes.last_analysis_results.ArcSight Threat Intelligence.engine_name      object
#  89   attributes.last_analysis_results.ArcSight Threat Intelligence.category         object
#  90   attributes.last_analysis_results.ArcSight Threat Intelligence.result           object
#  91   attributes.last_analysis_results.AutoShun.method                               object
#  92   attributes.last_analysis_results.AutoShun.engine_name                          object
#  93   attributes.last_analysis_results.AutoShun.category                             object
#  94   attributes.last_analysis_results.AutoShun.result                               object
#  95   attributes.last_analysis_results.benkow.cc.method                              object
#  96   attributes.last_analysis_results.benkow.cc.engine_name                         object
#  97   attributes.last_analysis_results.benkow.cc.category                            object
#  98   attributes.last_analysis_results.benkow.cc.result                              object
#  99   attributes.last_analysis_results.Bfore.Ai PreCrime.method                      object
#  100  attributes.last_analysis_results.Bfore.Ai PreCrime.engine_name                 object
#  101  attributes.last_analysis_results.Bfore.Ai PreCrime.category                    object
#  102  attributes.last_analysis_results.Bfore.Ai PreCrime.result                      object
#  103  attributes.last_analysis_results.BitDefender.method                            object
#  104  attributes.last_analysis_results.BitDefender.engine_name                       object
#  105  attributes.last_analysis_results.BitDefender.category                          object
#  106  attributes.last_analysis_results.BitDefender.result                            object
#  107  attributes.last_analysis_results.Bkav.method                                   object
#  108  attributes.last_analysis_results.Bkav.engine_name                              object
#  109  attributes.last_analysis_results.Bkav.category                                 object
#  110  attributes.last_analysis_results.Bkav.result                                   object
#  111  attributes.last_analysis_results.Blueliv.method                                object
#  112  attributes.last_analysis_results.Blueliv.engine_name                           object
#  113  attributes.last_analysis_results.Blueliv.category                              object
#  114  attributes.last_analysis_results.Blueliv.result                                object
#  115  attributes.last_analysis_results.Certego.method                                object
#  116  attributes.last_analysis_results.Certego.engine_name                           object
#  117  attributes.last_analysis_results.Certego.category                              object
#  118  attributes.last_analysis_results.Certego.result                                object
#  119  attributes.last_analysis_results.Chong Lua Dao.method                          object
#  120  attributes.last_analysis_results.Chong Lua Dao.engine_name                     object
#  121  attributes.last_analysis_results.Chong Lua Dao.category                        object
#  122  attributes.last_analysis_results.Chong Lua Dao.result                          object
#  123  attributes.last_analysis_results.CINS Army.method                              object
#  124  attributes.last_analysis_results.CINS Army.engine_name                         object
#  125  attributes.last_analysis_results.CINS Army.category                            object
#  126  attributes.last_analysis_results.CINS Army.result                              object
#  127  attributes.last_analysis_results.Cluster25.method                              object
#  128  attributes.last_analysis_results.Cluster25.engine_name                         object
#  129  attributes.last_analysis_results.Cluster25.category                            object
#  130  attributes.last_analysis_results.Cluster25.result                              object
#  131  attributes.last_analysis_results.CRDF.method                                   object
#  132  attributes.last_analysis_results.CRDF.engine_name                              object
#  133  attributes.last_analysis_results.CRDF.category                                 object
#  134  attributes.last_analysis_results.CRDF.result                                   object
#  135  attributes.last_analysis_results.CSIS Security Group.method                    object
#  136  attributes.last_analysis_results.CSIS Security Group.engine_name               object
#  137  attributes.last_analysis_results.CSIS Security Group.category                  object
#  138  attributes.last_analysis_results.CSIS Security Group.result                    object
#  139  attributes.last_analysis_results.Snort IP sample list.method                   object
#  140  attributes.last_analysis_results.Snort IP sample list.engine_name              object
#  141  attributes.last_analysis_results.Snort IP sample list.category                 object
#  142  attributes.last_analysis_results.Snort IP sample list.result                   object
#  143  attributes.last_analysis_results.CMC Threat Intelligence.method                object
#  144  attributes.last_analysis_results.CMC Threat Intelligence.engine_name           object
#  145  attributes.last_analysis_results.CMC Threat Intelligence.category              object
#  146  attributes.last_analysis_results.CMC Threat Intelligence.result                object
#  147  attributes.last_analysis_results.Cyan.method                                   object
#  148  attributes.last_analysis_results.Cyan.engine_name                              object
#  149  attributes.last_analysis_results.Cyan.category                                 object
#  150  attributes.last_analysis_results.Cyan.result                                   object
#  151  attributes.last_analysis_results.Cyble.method                                  object
#  152  attributes.last_analysis_results.Cyble.engine_name                             object
#  153  attributes.last_analysis_results.Cyble.category                                object
#  154  attributes.last_analysis_results.Cyble.result                                  object
#  155  attributes.last_analysis_results.CyRadar.method                                object
#  156  attributes.last_analysis_results.CyRadar.engine_name                           object
#  157  attributes.last_analysis_results.CyRadar.category                              object
#  158  attributes.last_analysis_results.CyRadar.result                                object
#  159  attributes.last_analysis_results.DNS8.method                                   object
#  160  attributes.last_analysis_results.DNS8.engine_name                              object
#  161  attributes.last_analysis_results.DNS8.category                                 object
#  162  attributes.last_analysis_results.DNS8.result                                   object
#  163  attributes.last_analysis_results.Dr.Web.method                                 object
#  164  attributes.last_analysis_results.Dr.Web.engine_name                            object
#  165  attributes.last_analysis_results.Dr.Web.category                               object
#  166  attributes.last_analysis_results.Dr.Web.result                                 object
#  167  attributes.last_analysis_results.Ermes.method                                  object
#  168  attributes.last_analysis_results.Ermes.engine_name                             object
#  169  attributes.last_analysis_results.Ermes.category                                object
#  170  attributes.last_analysis_results.Ermes.result                                  object
#  171  attributes.last_analysis_results.ESET.method                                   object
#  172  attributes.last_analysis_results.ESET.engine_name                              object
#  173  attributes.last_analysis_results.ESET.category                                 object
#  174  attributes.last_analysis_results.ESET.result                                   object
#  175  attributes.last_analysis_results.ESTsecurity.method                            object
#  176  attributes.last_analysis_results.ESTsecurity.engine_name                       object
#  177  attributes.last_analysis_results.ESTsecurity.category                          object
#  178  attributes.last_analysis_results.ESTsecurity.result                            object
#  179  attributes.last_analysis_results.EmergingThreats.method                        object
#  180  attributes.last_analysis_results.EmergingThreats.engine_name                   object
#  181  attributes.last_analysis_results.EmergingThreats.category                      object
#  182  attributes.last_analysis_results.EmergingThreats.result                        object
#  183  attributes.last_analysis_results.Emsisoft.method                               object
#  184  attributes.last_analysis_results.Emsisoft.engine_name                          object
#  185  attributes.last_analysis_results.Emsisoft.category                             object
#  186  attributes.last_analysis_results.Emsisoft.result                               object
#  187  attributes.last_analysis_results.Forcepoint ThreatSeeker.method                object
#  188  attributes.last_analysis_results.Forcepoint ThreatSeeker.engine_name           object
#  189  attributes.last_analysis_results.Forcepoint ThreatSeeker.category              object
#  190  attributes.last_analysis_results.Forcepoint ThreatSeeker.result                object
#  191  attributes.last_analysis_results.Fortinet.method                               object
#  192  attributes.last_analysis_results.Fortinet.engine_name                          object
#  193  attributes.last_analysis_results.Fortinet.category                             object
#  194  attributes.last_analysis_results.Fortinet.result                               object
#  195  attributes.last_analysis_results.G-Data.method                                 object
#  196  attributes.last_analysis_results.G-Data.engine_name                            object
#  197  attributes.last_analysis_results.G-Data.category                               object
#  198  attributes.last_analysis_results.G-Data.result                                 object
#  199  attributes.last_analysis_results.GCP Abuse Intelligence.method                 object
#  200  attributes.last_analysis_results.GCP Abuse Intelligence.engine_name            object
#  201  attributes.last_analysis_results.GCP Abuse Intelligence.category               object
#  202  attributes.last_analysis_results.GCP Abuse Intelligence.result                 object
#  203  attributes.last_analysis_results.Google Safebrowsing.method                    object
#  204  attributes.last_analysis_results.Google Safebrowsing.engine_name               object
#  205  attributes.last_analysis_results.Google Safebrowsing.category                  object
#  206  attributes.last_analysis_results.Google Safebrowsing.result                    object
#  207  attributes.last_analysis_results.GreenSnow.method                              object
#  208  attributes.last_analysis_results.GreenSnow.engine_name                         object
#  209  attributes.last_analysis_results.GreenSnow.category                            object
#  210  attributes.last_analysis_results.GreenSnow.result                              object
#  211  attributes.last_analysis_results.Gridinsoft.method                             object
#  212  attributes.last_analysis_results.Gridinsoft.engine_name                        object
#  213  attributes.last_analysis_results.Gridinsoft.category                           object
#  214  attributes.last_analysis_results.Gridinsoft.result                             object
#  215  attributes.last_analysis_results.Heimdal Security.method                       object
#  216  attributes.last_analysis_results.Heimdal Security.engine_name                  object
#  217  attributes.last_analysis_results.Heimdal Security.category                     object
#  218  attributes.last_analysis_results.Heimdal Security.result                       object
#  219  attributes.last_analysis_results.Hunt.io Intelligence.method                   object
#  220  attributes.last_analysis_results.Hunt.io Intelligence.engine_name              object
#  221  attributes.last_analysis_results.Hunt.io Intelligence.category                 object
#  222  attributes.last_analysis_results.Hunt.io Intelligence.result                   object
#  223  attributes.last_analysis_results.IPsum.method                                  object
#  224  attributes.last_analysis_results.IPsum.engine_name                             object
#  225  attributes.last_analysis_results.IPsum.category                                object
#  226  attributes.last_analysis_results.IPsum.result                                  object
#  227  attributes.last_analysis_results.Juniper Networks.method                       object
#  228  attributes.last_analysis_results.Juniper Networks.engine_name                  object
#  229  attributes.last_analysis_results.Juniper Networks.category                     object
#  230  attributes.last_analysis_results.Juniper Networks.result                       object
#  231  attributes.last_analysis_results.Kaspersky.method                              object
#  232  attributes.last_analysis_results.Kaspersky.engine_name                         object
#  233  attributes.last_analysis_results.Kaspersky.category                            object
#  234  attributes.last_analysis_results.Kaspersky.result                              object
#  235  attributes.last_analysis_results.Lionic.method                                 object
#  236  attributes.last_analysis_results.Lionic.engine_name                            object
#  237  attributes.last_analysis_results.Lionic.category                               object
#  238  attributes.last_analysis_results.Lionic.result                                 object
#  239  attributes.last_analysis_results.Lumu.method                                   object
#  240  attributes.last_analysis_results.Lumu.engine_name                              object
#  241  attributes.last_analysis_results.Lumu.category                                 object
#  242  attributes.last_analysis_results.Lumu.result                                   object
#  243  attributes.last_analysis_results.MalwarePatrol.method                          object
#  244  attributes.last_analysis_results.MalwarePatrol.engine_name                     object
#  245  attributes.last_analysis_results.MalwarePatrol.category                        object
#  246  attributes.last_analysis_results.MalwarePatrol.result                          object
#  247  attributes.last_analysis_results.MalwareURL.method                             object
#  248  attributes.last_analysis_results.MalwareURL.engine_name                        object
#  249  attributes.last_analysis_results.MalwareURL.category                           object
#  250  attributes.last_analysis_results.MalwareURL.result                             object
#  251  attributes.last_analysis_results.Malwared.method                               object
#  252  attributes.last_analysis_results.Malwared.engine_name                          object
#  253  attributes.last_analysis_results.Malwared.category                             object
#  254  attributes.last_analysis_results.Malwared.result                               object
#  255  attributes.last_analysis_results.Mimecast.method                               object
#  256  attributes.last_analysis_results.Mimecast.engine_name                          object
#  257  attributes.last_analysis_results.Mimecast.category                             object
#  258  attributes.last_analysis_results.Mimecast.result                               object
#  259  attributes.last_analysis_results.Netcraft.method                               object
#  260  attributes.last_analysis_results.Netcraft.engine_name                          object
#  261  attributes.last_analysis_results.Netcraft.category                             object
#  262  attributes.last_analysis_results.Netcraft.result                               object
#  263  attributes.last_analysis_results.OpenPhish.method                              object
#  264  attributes.last_analysis_results.OpenPhish.engine_name                         object
#  265  attributes.last_analysis_results.OpenPhish.category                            object
#  266  attributes.last_analysis_results.OpenPhish.result                              object
#  267  attributes.last_analysis_results.Phishing Database.method                      object
#  268  attributes.last_analysis_results.Phishing Database.engine_name                 object
#  269  attributes.last_analysis_results.Phishing Database.category                    object
#  270  attributes.last_analysis_results.Phishing Database.result                      object
#  271  attributes.last_analysis_results.PhishFort.method                              object
#  272  attributes.last_analysis_results.PhishFort.engine_name                         object
#  273  attributes.last_analysis_results.PhishFort.category                            object
#  274  attributes.last_analysis_results.PhishFort.result                              object
#  275  attributes.last_analysis_results.PhishLabs.method                              object
#  276  attributes.last_analysis_results.PhishLabs.engine_name                         object
#  277  attributes.last_analysis_results.PhishLabs.category                            object
#  278  attributes.last_analysis_results.PhishLabs.result                              object
#  279  attributes.last_analysis_results.Phishtank.method                              object
#  280  attributes.last_analysis_results.Phishtank.engine_name                         object
#  281  attributes.last_analysis_results.Phishtank.category                            object
#  282  attributes.last_analysis_results.Phishtank.result                              object
#  283  attributes.last_analysis_results.PREBYTES.method                               object
#  284  attributes.last_analysis_results.PREBYTES.engine_name                          object
#  285  attributes.last_analysis_results.PREBYTES.category                             object
#  286  attributes.last_analysis_results.PREBYTES.result                               object
#  287  attributes.last_analysis_results.PrecisionSec.method                           object
#  288  attributes.last_analysis_results.PrecisionSec.engine_name                      object
#  289  attributes.last_analysis_results.PrecisionSec.category                         object
#  290  attributes.last_analysis_results.PrecisionSec.result                           object
#  291  attributes.last_analysis_results.Quick Heal.method                             object
#  292  attributes.last_analysis_results.Quick Heal.engine_name                        object
#  293  attributes.last_analysis_results.Quick Heal.category                           object
#  294  attributes.last_analysis_results.Quick Heal.result                             object
#  295  attributes.last_analysis_results.Quttera.method                                object
#  296  attributes.last_analysis_results.Quttera.engine_name                           object
#  297  attributes.last_analysis_results.Quttera.category                              object
#  298  attributes.last_analysis_results.Quttera.result                                object
#  299  attributes.last_analysis_results.SafeToOpen.method                             object
#  300  attributes.last_analysis_results.SafeToOpen.engine_name                        object
#  301  attributes.last_analysis_results.SafeToOpen.category                           object
#  302  attributes.last_analysis_results.SafeToOpen.result                             object
#  303  attributes.last_analysis_results.Sansec eComscan.method                        object
#  304  attributes.last_analysis_results.Sansec eComscan.engine_name                   object
#  305  attributes.last_analysis_results.Sansec eComscan.category                      object
#  306  attributes.last_analysis_results.Sansec eComscan.result                        object
#  307  attributes.last_analysis_results.Scantitan.method                              object
#  308  attributes.last_analysis_results.Scantitan.engine_name                         object
#  309  attributes.last_analysis_results.Scantitan.category                            object
#  310  attributes.last_analysis_results.Scantitan.result                              object
#  311  attributes.last_analysis_results.SCUMWARE.org.method                           object
#  312  attributes.last_analysis_results.SCUMWARE.org.engine_name                      object
#  313  attributes.last_analysis_results.SCUMWARE.org.category                         object
#  314  attributes.last_analysis_results.SCUMWARE.org.result                           object
#  315  attributes.last_analysis_results.Seclookup.method                              object
#  316  attributes.last_analysis_results.Seclookup.engine_name                         object
#  317  attributes.last_analysis_results.Seclookup.category                            object
#  318  attributes.last_analysis_results.Seclookup.result                              object
#  319  attributes.last_analysis_results.SecureBrain.method                            object
#  320  attributes.last_analysis_results.SecureBrain.engine_name                       object
#  321  attributes.last_analysis_results.SecureBrain.category                          object
#  322  attributes.last_analysis_results.SecureBrain.result                            object
#  323  attributes.last_analysis_results.SOCRadar.method                               object
#  324  attributes.last_analysis_results.SOCRadar.engine_name                          object
#  325  attributes.last_analysis_results.SOCRadar.category                             object
#  326  attributes.last_analysis_results.SOCRadar.result                               object
#  327  attributes.last_analysis_results.Sophos.method                                 object
#  328  attributes.last_analysis_results.Sophos.engine_name                            object
#  329  attributes.last_analysis_results.Sophos.category                               object
#  330  attributes.last_analysis_results.Sophos.result                                 object
#  331  attributes.last_analysis_results.Spam404.method                                object
#  332  attributes.last_analysis_results.Spam404.engine_name                           object
#  333  attributes.last_analysis_results.Spam404.category                              object
#  334  attributes.last_analysis_results.Spam404.result                                object
#  335  attributes.last_analysis_results.StopForumSpam.method                          object
#  336  attributes.last_analysis_results.StopForumSpam.engine_name                     object
#  337  attributes.last_analysis_results.StopForumSpam.category                        object
#  338  attributes.last_analysis_results.StopForumSpam.result                          object
#  339  attributes.last_analysis_results.Sucuri SiteCheck.method                       object
#  340  attributes.last_analysis_results.Sucuri SiteCheck.engine_name                  object
#  341  attributes.last_analysis_results.Sucuri SiteCheck.category                     object
#  342  attributes.last_analysis_results.Sucuri SiteCheck.result                       object
#  343  attributes.last_analysis_results.ThreatHive.method                             object
#  344  attributes.last_analysis_results.ThreatHive.engine_name                        object
#  345  attributes.last_analysis_results.ThreatHive.category                           object
#  346  attributes.last_analysis_results.ThreatHive.result                             object
#  347  attributes.last_analysis_results.Threatsourcing.method                         object
#  348  attributes.last_analysis_results.Threatsourcing.engine_name                    object
#  349  attributes.last_analysis_results.Threatsourcing.category                       object
#  350  attributes.last_analysis_results.Threatsourcing.result                         object
#  351  attributes.last_analysis_results.Trustwave.method                              object
#  352  attributes.last_analysis_results.Trustwave.engine_name                         object
#  353  attributes.last_analysis_results.Trustwave.category                            object
#  354  attributes.last_analysis_results.Trustwave.result                              object
#  355  attributes.last_analysis_results.Underworld.method                             object
#  356  attributes.last_analysis_results.Underworld.engine_name                        object
#  357  attributes.last_analysis_results.Underworld.category                           object
#  358  attributes.last_analysis_results.Underworld.result                             object
#  359  attributes.last_analysis_results.URLhaus.method                                object
#  360  attributes.last_analysis_results.URLhaus.engine_name                           object
#  361  attributes.last_analysis_results.URLhaus.category                              object
#  362  attributes.last_analysis_results.URLhaus.result                                object
#  363  attributes.last_analysis_results.URLQuery.method                               object
#  364  attributes.last_analysis_results.URLQuery.engine_name                          object
#  365  attributes.last_analysis_results.URLQuery.category                             object
#  366  attributes.last_analysis_results.URLQuery.result                               object
#  367  attributes.last_analysis_results.Viettel Threat Intelligence.method            object
#  368  attributes.last_analysis_results.Viettel Threat Intelligence.engine_name       object
#  369  attributes.last_analysis_results.Viettel Threat Intelligence.category          object
#  370  attributes.last_analysis_results.Viettel Threat Intelligence.result            object
#  371  attributes.last_analysis_results.VIPRE.method                                  object
#  372  attributes.last_analysis_results.VIPRE.engine_name                             object
#  373  attributes.last_analysis_results.VIPRE.category                                object
#  374  attributes.last_analysis_results.VIPRE.result                                  object
#  375  attributes.last_analysis_results.VX Vault.method                               object
#  376  attributes.last_analysis_results.VX Vault.engine_name                          object
#  377  attributes.last_analysis_results.VX Vault.category                             object
#  378  attributes.last_analysis_results.VX Vault.result                               object
#  379  attributes.last_analysis_results.ViriBack.method                               object
#  380  attributes.last_analysis_results.ViriBack.engine_name                          object
#  381  attributes.last_analysis_results.ViriBack.category                             object
#  382  attributes.last_analysis_results.ViriBack.result                               object
#  383  attributes.last_analysis_results.Webroot.method                                object
#  384  attributes.last_analysis_results.Webroot.engine_name                           object
#  385  attributes.last_analysis_results.Webroot.category                              object
#  386  attributes.last_analysis_results.Webroot.result                                object
#  387  attributes.last_analysis_results.Yandex Safebrowsing.method                    object
#  388  attributes.last_analysis_results.Yandex Safebrowsing.engine_name               object
#  389  attributes.last_analysis_results.Yandex Safebrowsing.category                  object
#  390  attributes.last_analysis_results.Yandex Safebrowsing.result                    object
#  391  attributes.last_analysis_results.ZeroCERT.method                               object
#  392  attributes.last_analysis_results.ZeroCERT.engine_name                          object
#  393  attributes.last_analysis_results.ZeroCERT.category                             object
#  394  attributes.last_analysis_results.ZeroCERT.result                               object
#  395  attributes.last_analysis_results.desenmascara.me.method                        object
#  396  attributes.last_analysis_results.desenmascara.me.engine_name                   object
#  397  attributes.last_analysis_results.desenmascara.me.category                      object
#  398  attributes.last_analysis_results.desenmascara.me.result                        object
#  399  attributes.last_analysis_results.malwares.com URL checker.method               object
#  400  attributes.last_analysis_results.malwares.com URL checker.engine_name          object
#  401  attributes.last_analysis_results.malwares.com URL checker.category             object
#  402  attributes.last_analysis_results.malwares.com URL checker.result               object
#  403  attributes.last_analysis_results.securolytics.method                           object
#  404  attributes.last_analysis_results.securolytics.engine_name                      object
#  405  attributes.last_analysis_results.securolytics.category                         object
#  406  attributes.last_analysis_results.securolytics.result                           object
#  407  attributes.last_analysis_results.Xcitium Verdict Cloud.method                  object
#  408  attributes.last_analysis_results.Xcitium Verdict Cloud.engine_name             object
#  409  attributes.last_analysis_results.Xcitium Verdict Cloud.category                object
#  410  attributes.last_analysis_results.Xcitium Verdict Cloud.result                  object
#  411  attributes.last_analysis_results.zvelo.method                                  object
#  412  attributes.last_analysis_results.zvelo.engine_name                             object
#  413  attributes.last_analysis_results.zvelo.category                                object
#  414  attributes.last_analysis_results.zvelo.result                                  object
#  415  attributes.last_analysis_results.ZeroFox.method                                object
#  416  attributes.last_analysis_results.ZeroFox.engine_name                           object
#  417  attributes.last_analysis_results.ZeroFox.category                              object
#  418  attributes.last_analysis_results.ZeroFox.result                                object
#  419  attributes.tld                                                                 object
#  420  attributes.creation_date                                                       float64
#  421  attributes.categories.Sophos                                                   object
#  422  attributes.categories.alphaMountain.ai                                         object
#  423  attributes.whois                                                               object
#  424  attributes.last_analysis_stats.malicious                                       int64
#  425  attributes.last_analysis_stats.suspicious                                      int64
#  426  attributes.last_analysis_stats.undetected                                      int64
#  427  attributes.last_analysis_stats.harmless                                        int64
#  428  attributes.last_analysis_stats.timeout                                         int64
#  429  attributes.last_dns_records_date                                               float64
#  430  attributes.rdap.handle                                                         object
#  431  attributes.rdap.ldh_name                                                       object
#  432  attributes.rdap.unicode_name                                                   object
#  433  attributes.rdap.events                                                         object
#  434  attributes.rdap.links                                                          object
#  435  attributes.rdap.notices                                                        object
#  436  attributes.rdap.nameservers                                                    object
#  437  attributes.rdap.rdap_conformance                                               object
#  438  attributes.rdap.entities                                                       object
#  439  attributes.rdap.object_class_name                                              object
#  440  attributes.rdap.status                                                         object
#  441  attributes.rdap.secure_dns.delegation_signed                                   object
#  442  attributes.rdap.secure_dns.zone_signed                                         object
#  443  attributes.rdap.secure_dns.max_sig_life                                        float64
#  444  attributes.rdap.secure_dns.ds_data                                             object
#  445  attributes.rdap.secure_dns.key_data                                            object
#  446  attributes.rdap.port43                                                         object
#  447  attributes.rdap.lang                                                           object
#  448  attributes.rdap.punycode                                                       object
#  449  attributes.rdap.type                                                           object
#  450  attributes.rdap.switch_name                                                    object
#  451  attributes.rdap.public_ids                                                     object
#  452  attributes.rdap.remarks                                                        object
#  453  attributes.rdap.nask0_state                                                    object
#  454  attributes.rdap.variants                                                       object
#  455  attributes.last_https_certificate.extensions.ca_information_access.CA Issuers  object
#  456  attributes.last_https_certificate.extensions.ca_information_access.OCSP        object
#  457  attributes.last_https_certificate.extensions.certificate_policies              object
#  458  attributes.last_https_certificate.extensions.crl_distribution_points           object
#  459  attributes.last_https_certificate.extensions.subject_alternative_name          object
#  460  attributes.last_https_certificate.extensions.extended_key_usage                object
#  461  attributes.last_https_certificate.extensions.authority_key_identifier.keyid    object
#  462  attributes.last_https_certificate.extensions.subject_key_identifier            object
#  463  attributes.last_https_certificate.extensions.1.3.6.1.4.1.11129.2.4.2           object
#  464  attributes.rdap.start_address                                                  object
#  465  attributes.rdap.end_address                                                    object
#  466  attributes.rdap.ip_version                                                     object
#  467  attributes.rdap.name                                                           object
#  468  attributes.rdap.country                                                        object
#  469  attributes.rdap.parent_handle                                                  object
#  470  attributes.rdap.cidr0_cidrs                                                    object
#  471  attributes.rdap.arin_originas0_originautnums                                   object
#  472  attributes.continent                                                           object
#  473  attributes.regional_internet_registry                                          object
#  474  attributes.network                                                             object
#  475  attributes.asn                                                                 float64
#  476  attributes.country                                                             object
#  477  attributes.as_owner                                                            object
# dtypes: bool(1), float64(5), int64(14), object(458)
# memory usage: 7.6+ KB

# %%
df_abuse.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   _id                   1 non-null      object
#  1   ipAddress             1 non-null      object
#  2   isPublic              1 non-null      bool
#  3   ipVersion             1 non-null      int64
#  4   isWhitelisted         1 non-null      bool
#  5   abuseConfidenceScore  1 non-null      int64
#  6   countryCode           1 non-null      object
#  7   usageType             1 non-null      object
#  8   isp                   1 non-null      object
#  9   domain                1 non-null      object
#  10  hostnames             1 non-null      object
#  11  isTor                 1 non-null      bool
#  12  totalReports          1 non-null      int64
#  13  numDistinctUsers      1 non-null      int64
#  14  lastReportedAt        1 non-null      object
# dtypes: bool(3), int64(4), object(8)
# memory usage: 227.0+ bytes

# %%
df_whois.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   _id              1 non-null      object
#  1   handle           1 non-null      object
#  2   startAddress     1 non-null      object
#  3   endAddress       1 non-null      object
#  4   ipVersion        1 non-null      object
#  5   name             1 non-null      object
#  6   type             1 non-null      object
#  7   country          1 non-null      object
#  8   parentHandle     1 non-null      object
#  9   cidr0_cidrs      1 non-null      object
#  10  status           1 non-null      object
#  11  entities         1 non-null      object
#  12  links            1 non-null      object
#  13  events           1 non-null      object
#  14  rdapConformance  1 non-null      object
#  15  notices          1 non-null      object
#  16  port43           1 non-null      object
#  17  objectClassName  1 non-null      object
#  18  redacted         1 non-null      object
# dtypes: object(19)
# memory usage: 280.0+ bytes

# %%
df_shodan.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1 entries, 0 to 0
# Data columns (total 3 columns):
#  #   Column   Non-Null Count  Dtype
# ---  ------   --------------  -----
#  0   _id      1 non-null      object
#  1   matches  1 non-null      object
#  2   total    1 non-null      int64
# dtypes: int64(1), object(2)
# memory usage: 152.0+ bytes

# %% [markdown]
# #### Conclusión
#
# Note que la mayoría de los campos se pueden pensar como variables categóricas (geolocalización, registrants, veredictos de diferentes proveedores de ciberseguridad, algoritmos de encripción, registros dns, entre otros) Por lo que pensar en un modelo de datos, resulta una tarea que supera el alcance de este proyecto; sin embargo, sistemas como los LLMs sobresalen al poder trabajar con información en este formato, por lo que permite extraer o imitar la base de investigación de los operadores de ciberseguridad, automatizando incluso la extracción de información, y facilitando la potencial integración con otras arquitecturas de agentes, como la de Human In the Loop (HIL),
